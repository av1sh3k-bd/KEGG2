# %% [markdown]
# <a href="https://colab.research.google.com/github/av1sh3k-bd/KEGG2/blob/main/scrapping_kegg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (4.6.3)

# %% [markdown]
# Importing BeautifulSoup Library

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
import re

# %%
# specify the url
url = "https://www.genome.jp/pathway/bit01100+M00793"

# Connect to the website and return the html to the variable ‘page’
try:
    page = urlopen(url)
except:
    print("Error opening the URL")

# parse the html using beautiful soup and store in variable `soup`
soup = BeautifulSoup(page, 'html.parser')

# Take out the <div> of name and get its value
content = soup.find('ul', {"class": "tree module-tree"})
#print(content)
content=str(content)
#content = re.sub(r'(.*?)blank', '', content)

#print(content)
# article = ''
# for i in content.findAll('p'):
#     article = article + ' ' +  i.text
# print(article)

# # Saving the scraped text
# with open('scraped_text.txt', 'w') as file:
#     file.write(article)

# %%
# Python program to convert a list to string
    
# Function to convert  
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %%
#pattern=re.compile(r'k">M\w\w\w\w\w')

#pattern=re.compile(r'blank">M00001</a>\s*(\w*)')

pattern=re.compile(r'>M\w\w\w\w\w</a>\s*[a-zA-Z\s\(\)\-]*')


matches=pattern.findall(content)

matches=listToString(matches)


pattern2=re.compile(r'M\d\d\d\d\d')

map_ids=pattern2.findall(matches)

print(map_ids)

#print(matches)

# for match in matches:
#   #print(match)
#   map_id=match[3:]
#   print(map_id)

# for match in matches:
#   print(match)
# Out:
# ['M00001', 'M00002', 'M00003', 'M00307', 'M00009', 'M00010', 'M00011', 'M00004', 'M00006', 'M00007', 'M00580', 'M00005', 'M00008', 'M00308', 'M00633', 'M00309', 'M00014', 'M00630', 'M00631', 'M00061', 'M00081', 'M00632', 'M00552', 'M00129', 'M00114', 'M00550', 'M00854', 'M00855', 'M00565', 'M00549', 'M00554', 'M00909', 'M00761', 'M00012', 'M00373', 'M00740', 'M00532', 'M00013', 'M00741', 'M00130', 'M00131', 'M00132', 'M00165', 'M00166', 'M00167', 'M00168', 'M00169', 'M00172', 'M00171', 'M00170', 'M00173', 'M00376', 'M00375', 'M00374', 'M00377', 'M00579', 'M00620', 'M00567', 'M00357', 'M00356', 'M00563', 'M00358', 'M00608', 'M00174', 'M00346', 'M00345', 'M00344', 'M00378', 'M00935', 'M00422', 'M00175', 'M00531', 'M00530', 'M00529', 'M00528', 'M00804', 'M00176', 'M00596', 'M00595', 'M00082', 'M00083', 'M00873', 'M00874', 'M00085', 'M00415', 'M00086', 'M00087', 'M00861', 'M00101', 'M00102', 'M00917', 'M00103', 'M00104', 'M00106', 'M00862', 'M00107', 'M00108', 'M00109', 'M00110', 'M00088', 'M00089', 'M00098', 'M00090', 'M00091', 'M00092', 'M00093', 'M00094', 'M00066', 'M00067', 'M00099', 'M00100', 'M00113', 'M00048', 'M00049', 'M00050', 'M00546', 'M00051', 'M00052', 'M00053', 'M00938', 'M00046', 'M00939', 'M00020', 'M00018', 'M00555', 'M00033', 'M00919', 'M00021', 'M00338', 'M00609', 'M00017', 'M00034', 'M00035', 'M00368', 'M00019', 'M00535', 'M00570', 'M00432', 'M00036', 'M00016', 'M00525', 'M00526', 'M00527', 'M00030', 'M00433', 'M00031', 'M00032', 'M00028', 'M00763', 'M00844', 'M00845', 'M00029', 'M00015', 'M00047', 'M00879', 'M00133', 'M00134', 'M00135', 'M00136', 'M00026', 'M00045', 'M00022', 'M00023', 'M00024', 'M00910', 'M00025', 'M00040', 'M00042', 'M00043', 'M00044', 'M00533', 'M00037', 'M00936', 'M00038', 'M00027', 'M00369', 'M00118', 'M00947', 'M00948', 'M00949', 'M00055', 'M00072', 'M00073', 'M00074', 'M00075', 'M00056', 'M00872', 'M00065', 'M00070', 'M00071', 'M00068', 'M00069', 'M00057', 'M00058', 'M00059', 'M00076', 'M00077', 'M00078', 'M00079', 'M00060', 'M00866', 'M00867', 'M00063', 'M00064', 'M00922', 'M00923', 'M00127', 'M00895', 'M00896', 'M00897', 'M00898', 'M00899', 'M00125', 'M00911', 'M00124', 'M00916', 'M00115', 'M00912', 'M00810', 'M00811', 'M00622', 'M00119', 'M00913', 'M00120', 'M00914', 'M00572', 'M00123', 'M00573', 'M00577', 'M00881', 'M00882', 'M00883', 'M00884', 'M00126', 'M00840', 'M00841', 'M00842', 'M00843', 'M00880', 'M00140', 'M00846', 'M00868', 'M00121', 'M00926', 'M00847', 'M00924', 'M00925', 'M00122', 'M00836', 'M00117', 'M00128', 'M00116', 'M00930', 'M00931', 'M00932', 'M00112', 'M00933', 'M00095', 'M00849', 'M00096', 'M00364', 'M00097', 'M00372', 'M00371', 'M00927', 'M00928', 'M00929', 'M00773', 'M00934', 'M00774', 'M00775', 'M00776', 'M00777', 'M00824', 'M00825', 'M00826', 'M00827', 'M00828', 'M00829', 'M00830', 'M00831', 'M00832', 'M00834', 'M00833', 'M00778', 'M00779', 'M00780', 'M00823', 'M00781', 'M00782', 'M00783', 'M00784', 'M00793', 'M00794', 'M00795', 'M00796', 'M00797', 'M00798', 'M00799', 'M00800', 'M00801', 'M00802', 'M00803', 'M00039', 'M00137', 'M00940', 'M00138', 'M00941', 'M00942', 'M00943', 'M00944', 'M00945', 'M00946', 'M00370', 'M00900', 'M00894', 'M00902', 'M00672', 'M00673', 'M00675', 'M00736', 'M00674', 'M00877', 'M00889', 'M00815', 'M00904', 'M00785', 'M00787', 'M00848', 'M00788', 'M00819', 'M00903', 'M00890', 'M00661', 'M00786', 'M00937', 'M00893', 'M00891', 'M00901', 'M00814', 'M00789', 'M00790', 'M00805', 'M00808', 'M00835', 'M00837', 'M00838', 'M00921', 'M00905', 'M00876', 'M00875', 'M00918', 'M00906', 'M00538', 'M00537', 'M00419', 'M00547', 'M00548', 'M00551', 'M00637', 'M00568', 'M00569', 'M00539', 'M00543', 'M00544', 'M00418', 'M00541', 'M00540', 'M00534', 'M00638', 'M00624', 'M00623', 'M00636', 'M00878', 'M00545', 'M00915']

# %%
#print(matches)

pathway_content=re.sub(r'(.*?)>\s*','',matches)
#pathway_content=re.sub(r'(\s)*\w','',pathway_content)

#pathway_content=pathway_content.replace("\n","")

print(pathway_content)

pathway_pattern=re.compile(r'[a-zA-Z]')

pathway_match=pathway_pattern.findall(matches)

for line in textData.splitlines():
    print(line)
    lineResult = libLAPFF.parseLine(line)
# Out:
# Glycolysis (Embden-Meyerhof pathway)
#
# Gluconeogenesis
#
# Pyruvate oxidation
#
# Pentose phosphate pathway (Pentose phosphate cycle)
#
# PRPP biosynthesis
#
# Entner-Doudoroff pathway
#
# Semi-phosphorylative Entner-Doudoroff pathway
#
# Semi-phosphorylative Entner-Doudoroff pathway
#
# Non-phosphorylative Entner-Doudoroff pathway
#
# Glucuronate pathway (uronate pathway)
#
# D-Galacturonate degradation (fungi)
#
# D-Galacturonate degradation (bacteria)
#
# D-Glucuronate degradation
#
# Pectin degradation
#
# Ascorbate degradation
#
# Glycogen biosynthesis
#
# Glycogen degradation
#
# Trehalose biosynthesis
#
# Nucleotide sugar biosynthesis
#
# Nucleotide sugar biosynthesis
#
# Glyoxylate cycle
#
# Ethylmalonyl pathway
#
# Methylaspartate cycle
#
# Photorespiration
#
# Malonate semialdehyde pathway
#
# Propanoyl-CoA metabolism
#
# Inositol phosphate metabolism
#
# Inositol phosphate metabolism
#
# Inositol phosphate metabolism
#
# Reductive pentose phosphate cycle (Calvin cycle)
#
# Reductive pentose phosphate cycle
#
# Reductive pentose phosphate cycle
#
# Reductive citrate cycle (Arnon-Buchanan cycle)
#
# Hydroxypropionate-hydroxybutylate cycle
#
# Dicarboxylate-hydroxybutyrate cycle
#
# Reductive acetyl-CoA pathway (Wood-Ljungdahl pathway)
#
# Phosphate acetyltransferase-acetate kinase pathway
#
# Incomplete reductive citrate cycle
#
# Methanogenesis
#
# Methanogenesis
#
# Methanogenesis
#
# Methanogenesis
#
# Coenzyme M biosynthesis
#
# Methanofuran biosynthesis
#
# Acetyl-CoA pathway
#
# Nitrogen fixation
#
# Assimilatory nitrate reduction
#
# Dissimilatory nitrate reduction
#
# Denitrification
#
# Nitrification
#
# Assimilatory sulfate reduction
#
# Dissimilatory sulfate reduction
#
# Thiosulfate oxidation by SOX complex
#
# Fatty acid elongation in mitochondria
#
# Fatty acid elongation in endoplasmic reticulum
#
# beta-Oxidation
#
# Cholesterol biosynthesis
#
# Ergocalciferol biosynthesis
#
# Phytosterol biosynthesis
#
# Cholecalciferol biosynthesis
#
# Bile acid biosynthesis
#
# Conjugated bile acid biosynthesis
#
# Steroid hormone biosynthesis
#
# Ketone body biosynthesis
#
# Triacylglycerol biosynthesis
#
# Acylglycerol degradation
#
# Phosphatidylcholine (PC) biosynthesis
#
# Phosphatidylcholine (PC) biosynthesis
#
# Phosphatidylethanolamine (PE) biosynthesis
#
# Phosphatidylethanolamine (PE) biosynthesis
#
# Ceramide biosynthesis
#
# Lactosylceramide biosynthesis
#
# Sulfoglycolipids biosynthesis
#
# Sphingosine biosynthesis
#
# Sphingosine degradation
#
# Jasmonic acid biosynthesis
#
# Inosine monophosphate biosynthesis
#
# Adenine ribonucleotide biosynthesis
#
# Guanine ribonucleotide biosynthesis
#
# Purine degradation
#
# Uridine monophosphate biosynthesis
#
# Pyrimidine ribonucleotide biosynthesis
#
# Pyrimidine deoxyribonuleotide biosynthesis
#
# Pyrimidine deoxyribonuleotide biosynthesis
#
# Pyrimidine degradation
#
# Pyrimidine degradation
#
# Serine biosynthesis
#
# Threonine biosynthesis
#
# Betaine biosynthesis
#
# Ectoine biosynthesis
#
# Ectoine degradation
#
# Cysteine biosynthesis
#
# Cysteine biosynthesis
#
# Cysteine biosynthesis
#
# Methionine biosynthesis
#
# Methionine salvage pathway
#
# Methionine degradation
#
# Ethylene biosynthesis
#
# Isoleucine biosynthesis
#
# Isoleucine biosynthesis
#
# Leucine biosynthesis
#
# Leucine degradation
#
# Lysine biosynthesis
#
# Lysine degradation
#
# Ornithine biosynthesis
#
# Arginine biosynthesis
#
# Arginine biosynthesis
#
# Urea cycle
#
# Proline biosynthesis
#
# Creatine pathway
#
# Arginine succinyltransferase pathway
#
# Polyamine biosynthesis
#
# Polyamine biosynthesis
#
# Histidine biosynthesis
#
# Histidine degradation
#
# Shikimate pathway
#
# Tryptophan biosynthesis
#
# Phenylalanine biosynthesis
#
# Phenylalanine biosynthesis
#
# Tyrosine biosynthesis
#
# Tyrosine biosynthesis
#
# Catecholamine biosynthesis
#
# Thyroid hormone biosynthesis
#
# Tyrosine degradation
#
# Homoprotocatechuate degradation
#
# Tryptophan metabolism
#
# GABA (gamma-Aminobutyrate) shunt
#
# Cyanogenic glycoside biosynthesis
#
# Glutathione biosynthesis
#
# D-Arginine racemization
#
# Hydroxyproline degradation
#
# Staphylopine biosynthesis
#
# N-glycan precursor biosynthesis
#
# N-glycosylation by oligosaccharyltransferase
#
# N-glycan precursor trimming
#
# Dermatan sulfate degradation
#
# Chondroitin sulfate degradation
#
# Heparan sulfate degradation
#
# Keratan sulfate degradation
#
# CMP-KDO biosynthesis
#
# ADP-L-glycero-D-manno-heptose biosynthesis
#
# UDP-L-FucNAm biosynthesis
#
# Thiamine biosynthesis
#
# Thiamine salvage pathway
#
# Pyridoxal-P biosynthesis
#
# Pyridoxal-P biosynthesis
#
# NAD biosynthesis
#
# NAD biosynthesis
#
# Nicotinate degradation
#
# Pantothenate biosynthesis
#
# Pantothenate biosynthesis
#
# Coenzyme A biosynthesis
#
# Biotin biosynthesis
#
# Lipoic acid biosynthesis
#
# Tetrahydrofolate biosynthesis
#
# Tetrahydrobiopterin biosynthesis
#
# L-threo-Tetrahydrobiopterin biosynthesis
#
# Molybdenum cofactor biosynthesis
#
# Siroheme biosynthesis
#
# Cobalamin biosynthesis
#
# Menaquinone biosynthesis
#
# Phylloquinone biosynthesis
#
# Plastoquinone biosynthesis
#
# beta-Carotene biosynthesis
#
# Abscisic acid biosynthesis
#
# Castasterone biosynthesis
#
# Tylosin biosynthesis
#
# Mycinamicin biosynthesis
#
# Erythromycin biosynthesis
#
# Oleandomycin biosynthesis
#
# Avermectin biosynthesis
#
# Maduropeptin beta-hydroxy acid moiety biosynthesis
#
# Neocarzinostatin naphthoate moiety biosynthesis
#
# Calicheamicin orsellinate moiety biosynthesis
#
# Calicheamicin biosynthesis
#
# Type II polyketide backbone biosynthesis
#
# Dihydrokalafungin biosynthesis
#
# Chlortetracycline biosynthesis
#
# Mithramycin biosynthesis
#
# Elloramycin biosynthesis
#
# dTDP-L-rhamnose biosynthesis
#
# dTDP-beta-L-noviose biosynthesis
#
# dTDP-D-mycaminose biosynthesis
#
# dTDP-D-desosamine biosynthesis
#
# dTDP-L-mycarose biosynthesis
#
# dTDP-L-oleandrose biosynthesis
#
# dTDP-L-megosamine biosynthesis
#
# dTDP-L-olivose biosynthesis
#
# dTDP-D-forosamine biosynthesis
#
# dTDP-D-angolosamine biosynthesis
#
# Monolignol biosynthesis
#
# Flavanone biosynthesis
#
# Flavanone biosynthesis
#
# Flavonoid biosynthesis
#
# Isoflavone biosynthesis
#
# Pterocarpan biosynthesis
#
# Reticuline biosynthesis
#
# Morphine biosynthesis
#
# Sanguinarine biosynthesis
#
# Noscapine biosynthesis
#
# Glucosinolate biosynthesis
#
# Cronin biosynthesis
#
# Cannabidiol biosynthesis
#
# Podophyllotoxin biosynthesis
#
# Penicillin biosynthesis
#
# Cephamycin C biosynthesis
#
# Nocardicin A biosynthesis
#
# Clavaminate biosynthesis
#
# Puromycin biosynthesis
#
# Validamycin A biosynthesis
#
# Dapdiamides biosynthesis
#
# Cycloserine biosynthesis
#
# Bacilysin biosynthesis
#
# Aurachin biosynthesis
#
# Terpentecin biosynthesis
#
# Pentalenolactone biosynthesis
#
# Fosfomycin biosynthesis
#
# Roseoflavin biosynthesis
#
# Paspaline biosynthesis
#
# Fumitremorgin alkaloid biosynthesis
#
# Aflatoxin biosynthesis
#
# Lovastatin biosynthesis
#
# Ditryptophenaline biosynthesis
#
# Fumiquinazoline biosynthesis
#
# Acarbose biosynthesis
#
# Rebeccamycin biosynthesis
#
# Pyrrolnitrin biosynthesis
#
# Staurosporine biosynthesis
#
# Violacein biosynthesis
#
# Pyocyanine biosynthesis
#
# Prodigiosin biosynthesis
#
# Undecylprodigiosin biosynthesis
#
# Cyclooctatin biosynthesis
#
# Grixazone biosynthesis
#
# Staphyloferrin A biosynthesis
#
# Staphyloferrin B biosynthesis
#
# Aerobactin biosynthesis
#
# Ethynylserine biosynthesis
#
# Toluene degradation
#
# Xylene degradation
#
# Cymene degradation
#
# Benzene degradation
#
# Benzoate degradation
#
# Anthranilate degradation
#
# Catechol ortho-cleavage
#
# Catechol meta-cleavage
#
# Cumate degradation
#
# Biphenyl degradation
#
# Carbazole degradation
#
# Benzoyl-CoA degradation
#
# Benzoate degradation
#
# Naphthalene degradation
#
# Salicylate degradation
#
# Terephthalate degradation
#
# Phthalate degradation
#
# Phthalate degradation
#
# Phenylacetate degradation
#
# Trans-cinnamate degradation
#
# Caffeine degradation

# %%
pathway_list = pathway_content.split("\n\n")
pathway_list = list(set(pathway_list))   #removes duplicates
print(pathway_list)
# Out:
# ['Pentalenolactone biosynthesis', 'Ceramide biosynthesis', 'Sphingosine biosynthesis', 'UDP-L-FucNAm biosynthesis', 'Biotin biosynthesis', 'beta-Carotene biosynthesis', 'Sulfoglycolipids biosynthesis', 'Prodigiosin biosynthesis', 'Coenzyme M biosynthesis', 'dTDP-D-desosamine biosynthesis', 'Staphyloferrin A biosynthesis', 'Leucine biosynthesis', 'Glutathione biosynthesis', 'Mycinamicin biosynthesis', 'Cysteine biosynthesis', 'Undecylprodigiosin biosynthesis', 'Nicotinate degradation', 'Staphylopine biosynthesis', 'Conjugated bile acid biosynthesis', 'Thyroid hormone biosynthesis', 'Clavaminate biosynthesis', 'Propanoyl-CoA metabolism', 'Histidine degradation', 'Rebeccamycin biosynthesis', '\t\t', 'N-glycosylation by oligosaccharyltransferase', 'Heparan sulfate degradation', 'Lysine degradation', 'Catecholamine biosynthesis', 'Phosphate acetyltransferase-acetate kinase pathway', 'Phosphatidylethanolamine (PE) biosynthesis', 'Anthranilate degradation', 'Tryptophan biosynthesis', 'Leucine degradation', 'Flavanone biosynthesis', 'Biphenyl degradation', 'Benzene degradation', 'N-glycan precursor biosynthesis', 'Phenylalanine biosynthesis', 'Trehalose biosynthesis', 'Calicheamicin orsellinate moiety biosynthesis', 'Ditryptophenaline biosynthesis', 'Sanguinarine biosynthesis', 'Aflatoxin biosynthesis', 'Nucleotide sugar biosynthesis', 'Elloramycin biosynthesis', 'Keratan sulfate degradation', 'Podophyllotoxin biosynthesis', 'Cyclooctatin biosynthesis', 'Lactosylceramide biosynthesis', 'Dissimilatory sulfate reduction', 'PRPP biosynthesis', 'Noscapine biosynthesis', 'Benzoate degradation', 'Ethylmalonyl pathway', 'Fatty acid elongation in mitochondria', 'Penicillin biosynthesis', 'Thiamine biosynthesis', 'Fosfomycin biosynthesis', 'Glycolysis (Embden-Meyerhof pathway)', 'dTDP-L-olivose biosynthesis', 'Shikimate pathway', 'Incomplete reductive citrate cycle', 'Staphyloferrin B biosynthesis', 'beta-Oxidation', 'Dicarboxylate-hydroxybutyrate cycle', 'Plastoquinone biosynthesis', 'Toluene degradation', 'Glyoxylate cycle', 'Jasmonic acid biosynthesis', 'Glycogen biosynthesis', 'Tetrahydrobiopterin biosynthesis', 'Terpentecin biosynthesis', 'Isoleucine biosynthesis', 'Terephthalate degradation', 'Xylene degradation', 'Bile acid biosynthesis', 'Cobalamin biosynthesis', 'Trans-cinnamate degradation', 'Pyrimidine deoxyribonuleotide biosynthesis', 'Ethylene biosynthesis', 'Ectoine degradation', 'Cycloserine biosynthesis', 'Maduropeptin beta-hydroxy acid moiety biosynthesis', 'Glucosinolate biosynthesis', 'Creatine pathway', 'Reductive citrate cycle (Arnon-Buchanan cycle)', 'Reticuline biosynthesis', 'Aurachin biosynthesis', 'Thiamine salvage pathway', 'Monolignol biosynthesis', 'Isoflavone biosynthesis', 'Polyamine biosynthesis', 'Dermatan sulfate degradation', 'Dihydrokalafungin biosynthesis', 'Assimilatory nitrate reduction', 'Dapdiamides biosynthesis', 'Catechol ortho-cleavage', 'Glucuronate pathway (uronate pathway)', 'D-Galacturonate degradation (fungi)', 'Assimilatory sulfate reduction', 'Serine biosynthesis', 'Methionine degradation', 'Histidine biosynthesis', 'Malonate semialdehyde pathway', 'Pterocarpan biosynthesis', 'Chlortetracycline biosynthesis', 'Violacein biosynthesis', 'dTDP-L-oleandrose biosynthesis', 'Cymene degradation', 'Entner-Doudoroff pathway', 'Pyrimidine ribonucleotide biosynthesis', 'Phytosterol biosynthesis', 'Phylloquinone biosynthesis', 'Methylaspartate cycle', 'Cumate degradation', 'Glycogen degradation', 'Mithramycin biosynthesis', 'Pyocyanine biosynthesis', 'Oleandomycin biosynthesis', 'Arginine biosynthesis', 'Betaine biosynthesis', 'Cephamycin C biosynthesis', 'Steroid hormone biosynthesis', 'Pentose phosphate pathway (Pentose phosphate cycle)', 'Methanofuran biosynthesis', 'L-threo-Tetrahydrobiopterin biosynthesis', 'Fumiquinazoline biosynthesis', 'Phthalate degradation', 'ADP-L-glycero-D-manno-heptose biosynthesis', 'Adenine ribonucleotide biosynthesis', 'Nocardicin A biosynthesis', 'Validamycin A biosynthes ...

# %%
# !pip install Bio
# Out:
# Collecting Bio
#   Downloading bio-1.3.3-py3-none-any.whl (271 kB)
#      |████████████████████████████████| 271 kB 8.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from Bio) (2.23.0)
# Collecting mygene
#   Downloading mygene-3.2.2-py2.py3-none-any.whl (5.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from Bio) (4.62.3)
# Collecting biopython>=1.79
#   Downloading biopython-1.79-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 40.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biopython>=1.79->Bio) (1.19.5)
# Collecting biothings-client>=0.2.6
#   Downloading biothings_client-0.2.6-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->Bio) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->Bio) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->Bio) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->Bio) (3.0.4)
# Installing collected packages: biothings-client, mygene, biopython, Bio
# Successfully installed Bio-1.3.3 biopython-1.79 biothings-client-0.2.6 mygene-3.2.2

# %%
# !pip install Biopython
# Out:
# Requirement already satisfied: Biopython in /usr/local/lib/python3.7/dist-packages (1.79)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from Biopython) (1.19.5)

# %%
# Show plots as part of the notebook
# %matplotlib inline

# Show images inline
from IPython.display import Image

# Standard library packages
import io
import os

# Import Biopython modules to interact with KEGG
from Bio import SeqIO
from Bio.KEGG import REST
from Bio.KEGG.KGML import KGML_parser


# Import Pandas, so we can use dataframes
import pandas as pd

# %%
# Some code to return a Pandas dataframe, given tabular text
def to_df(result):
    return pd.read_table(io.StringIO(result), header=None)

# %%
result = REST.kegg_list("pathway","ec").read()
df=to_df(result)
df.loc[df[1] == "Pentalenolactone biosynthesis"]
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []

# %%
# Get genes involved with fatty-acid biosynthesis in Kitasatospora
result = REST.kegg_link("ec", "ec00010").read()
to_df(result)
